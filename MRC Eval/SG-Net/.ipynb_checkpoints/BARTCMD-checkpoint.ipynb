# %%
# !python run_squad2a.py --bert_model bert-base-cased --do_predict --predict_batch_size 20 --num_train_epochs 3.0 --max_seq_length 384 --doc_stride 128 --learning_rate 3e-5 --output_dir output_path --predict_file after_3_epochs.csv --predict_tag_file dev_span_sa.json
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# 08/07/2024 16:59:39 - INFO - __main__ -   device: cuda n_gpu: 1, distributed training: False, 16-bits training: False
# 08/07/2024 16:59:39 - INFO - pytorch_pretrained_bert.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased-vocab.txt from cache at /home/hmoradis/.cache/torch/pytorch_transformers/5e8a2b4893d13790ed4150ca1906be5f7a03d6c4ddf62296c383f6db42814db2.e13dbb970cb325137104fb2e5f36fe865f27746c6b526f6352861b1980eb80b1
# 08/07/2024 16:59:39 - INFO - pytorch_pretrained_bert.modeling -   loading archive file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased.tar.gz from cache at /home/hmoradis/.cache/torch/pytorch_transformers/distributed_-1/a803ce83ca27fecf74c355673c434e51c265fb8a3e0e57ac62a80e38ba98d384.681017f415dfb33ec8d0e04fe51a619f3f01532ecea04edbfd48c5d160550d9c
# 08/07/2024 16:59:39 - INFO - pytorch_pretrained_bert.modeling -   extracting archive file /home/hmoradis/.cache/torch/pytorch_transformers/distributed_-1/a803ce83ca27fecf74c355673c434e51c265fb8a3e0e57ac62a80e38ba98d384.681017f415dfb33ec8d0e04fe51a619f3f01532ecea04edbfd48c5d160550d9c to temp dir /tmp/tmpmbce9r4u
# 08/07/2024 16:59:41 - INFO - pytorch_pretrained_bert.modeling -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "type_vocab_size": 2,
#   "vocab_size": 28996
# }
#
# 08/07/2024 16:59:43 - INFO - pytorch_pretrained_bert.modeling -   Weights of BertForQuestionAnsweringSpanMask not initialized from pretrained model: ['w', 'gamma', 'bert.encoder.layer.0.attention.self.parse_query.weight', 'bert.encoder.layer.0.attention.self.parse_query.bias', 'bert.encoder.layer.0.attention.self.parse_key.weight', 'bert.encoder.layer.0.attention.self.parse_key.bias', 'bert.encoder.layer.0.attention.self.parse_value.weight', 'bert.encoder.layer.0.attention.self.parse_value.bias', 'bert.encoder.layer.0.attention.self.mlp.weight', 'bert.encoder.layer.0.attention.self.mlp.bias', 'bert.encoder.layer.1.attention.self.parse_query.weight', 'bert.encoder.layer.1.attention.self.parse_query.bias', 'bert.encoder.layer.1.attention.self.parse_key.weight', 'bert.encoder.layer.1.attention.self.parse_key.bias', 'bert.encoder.layer.1.attention.self.parse_value.weight', 'bert.encoder.layer.1.attention.self.parse_value.bias', 'bert.encoder.layer.1.attention.self.mlp.weight', 'bert.encoder.layer.1.attention.self.mlp.bias', 'bert.encoder.layer.2.attention.self.parse_query.weight', 'bert.encoder.layer.2.attention.self.parse_query.bias', 'bert.encoder.layer.2.attention.self.parse_key.weight', 'bert.encoder.layer.2.attention.self.parse_key.bias', 'bert.encoder.layer.2.attention.self.parse_value.weight', 'bert.encoder.layer.2.attention.self.parse_value.bias', 'bert.encoder.layer.2.attention.self.mlp.weight', 'bert.encoder.layer.2.attention.self.mlp.bias', 'bert.encoder.layer.3.attention.self.parse_query.weight', 'bert.encoder.layer.3.attention.self.parse_query.bias', 'bert.encoder.layer.3.attention.self.parse_key.weight', 'bert.encoder.layer.3.attention.self.parse_key.bias', 'bert.encoder.layer.3.attention.self.parse_value.weight', 'bert.encoder.layer.3.attention.self.parse_value.bias', 'bert.encoder.layer.3.attention.self.mlp.weight', 'bert.encoder.layer.3.attention.self.mlp.bias', 'bert.encoder.layer.4.attention.self.parse_query.weight', 'bert.encoder.layer.4.attention.self.parse_query.bias', 'bert.encoder.layer.4.attention.self.parse_key.weight', 'bert.encoder.layer.4.attention.self.parse_key.bias', 'bert.encoder.layer.4.attention.self.parse_value.weight', 'bert.encoder.layer.4.attention.self.parse_value.bias', 'bert.encoder.layer.4.attention.self.mlp.weight', 'bert.encoder.layer.4.attention.self.mlp.bias', 'bert.encoder.layer.5.attention.self.parse_query.weight', 'bert.encoder.layer.5.attention.self.parse_query.bias', 'bert.encoder.layer.5.attention.self.parse_key.weight', 'bert.encoder.layer.5.attention.self.parse_key.bias', 'bert.encoder.layer.5.attention.self.parse_value.weight', 'bert.encoder.layer.5.attention.self.parse_value.bias', 'bert.encoder.layer.5.attention.self.mlp.weight', 'bert.encoder.layer.5.attention.self.mlp.bias', 'bert.encoder.layer.6.attention.self.parse_query.weight', 'bert.encoder.layer.6.attention.self.parse_query.bias', 'bert.encoder.layer.6.attention.self.parse_key.weight', 'bert.encoder.layer.6.attention.self.parse_key.bias', 'bert.encoder.layer.6.attention.self.parse_value.weight', 'bert.encoder.layer.6.attention.self.parse_value.bias', 'bert.encoder.layer.6.attention.self.mlp.weight', 'bert.encoder.layer.6.attention.self.mlp.bias', 'bert.encoder.layer.7.attention.self.parse_query.weight', 'bert.encoder.layer.7.attention.self.parse_query.bias', 'bert.encoder.layer.7.attention.self.parse_key.weight', 'bert.encoder.layer.7.attention.self.parse_key.bias', 'bert.encoder.layer.7.attention.self.parse_value.weight', 'bert.encoder.layer.7.attention.self.parse_value.bias', 'bert.encoder.layer.7.attention.self.mlp.weight', 'bert.encoder.layer.7.attention.self.mlp.bias', 'bert.encoder.layer.8.attention.self.parse_query.weight', 'bert.encoder.layer.8.attention.self.parse_query.bias', 'bert.encoder.layer.8.attention.self.parse_key.weight', 'bert.encoder.layer.8.attention.self.parse_key.bias', 'bert.encoder.layer.8.attention.self.parse_value.weight', 'bert.encoder.layer.8.attention.self.parse_value.bias', 'bert.enco ...
# 08/07/2024 16:59:43 - INFO - pytorch_pretrained_bert.modeling -   Weights from pretrained model not used in BertForQuestionAnsweringSpanMask: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# reading dev...
# Not among us
# [Errno 2] No such file or directory: 'output_path/epoch_3_bart_predictions.json'
# 100%|███████| 5945/5945 [00:01<00:00, 4648.22it/s]
#   0%|                    | 0/5945 [00:00<?, ?it/s]/home/hmoradis/.conda/envs/QA_env/lib/python3.11/site-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# 100%|████████| 5945/5945 [00:38<00:00, 152.96it/s]
#
#
#
#
# qas_id: 5ad39d53604f3c001a3fe8d1, question_text: How did the Normans give their name to Normandy in the 1000's and 1100's?, doc_tokens: [The Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who in the 10th and 11th centuries gave their name to Normandy, a region in France. They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from Denmark, Iceland and Norway who, under their leader Rollo, agreed to swear fealty to King Charles III of West Francia. Through generations of assimilation and mixing with the native Frankish and Roman-Gaulish populations, their descendants would gradually merge with the Carolingian-based cultures of West Francia. The distinct cultural and ethnic identity of the Normans emerged initially in the first half of the 10th century, and it continued to evolve over the succeeding centuries.]
# qas_id: 5ad28ad0d7d075001a4299cf, question_text: What force is part of the modern SI system?, doc_tokens: [The pound-force has a metric counterpart, less commonly used than the newton: the kilogram-force (kgf) (sometimes kilopond), is the force exerted by standard gravity on one kilogram of mass. The kilogram-force leads to an alternate, but rarely used unit of mass: the metric slug (sometimes mug or hyl) is that mass that accelerates at 1 m·s−2 when subjected to a force of 1 kgf. The kilogram-force is not a part of the modern SI system, and is generally deprecated; however it still sees use for some purposes as expressing aircraft weight, jet thrust, bicycle spoke tension, torque wrench settings and engine output torque. Other arcane units of force include the sthène, which is equivalent to 1000 N, and the kip, which is equivalent to 1000 lbf.]
# 5945
#
#
#
#
# 08/07/2024 17:00:29 - INFO - pytorch_pretrained_bert.modeling -   loading archive file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased.tar.gz from cache at /home/hmoradis/.cache/torch/pytorch_transformers/a803ce83ca27fecf74c355673c434e51c265fb8a3e0e57ac62a80e38ba98d384.681017f415dfb33ec8d0e04fe51a619f3f01532ecea04edbfd48c5d160550d9c
# 08/07/2024 17:00:29 - INFO - pytorch_pretrained_bert.modeling -   extracting archive file /home/hmoradis/.cache/torch/pytorch_transformers/a803ce83ca27fecf74c355673c434e51c265fb8a3e0e57ac62a80e38ba98d384.681017f415dfb33ec8d0e04fe51a619f3f01532ecea04edbfd48c5d160550d9c to temp dir /tmp/tmpm63b3k_8
# 08/07/2024 17:00:31 - INFO - pytorch_pretrained_bert.modeling -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "type_vocab_size": 2,
#   "vocab_size": 28996
# }
#
# 08/07/2024 17:00:32 - INFO - pytorch_pretrained_bert.modeling -   Weights of BertForQuestionAnsweringSpanMask not initialized from pretrained model: ['gamma']
# 08/07/2024 17:00:32 - INFO - pytorch_pretrained_bert.modeling -   Weights from pretrained model not used in BertForQuestionAnsweringSpanMask: ['weight']
# 08/07/2024 17:00:32 - INFO - __main__ -   Start evaluating
# 08/07/2024 17:00:32 - INFO - __main__ -   Processing example: 0
# /home/hmoradis/UQA/Julien/Task22-our_MTL/Bart/MRC Eval/SG-Net/pytorch_pretrained_bert/modeling.py:1370: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   w = F.softmax(self.w)
# 08/07/2024 17:00:33 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:33 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# [Errno 2] No such file or directory: 'output_path/epoch_2_predictions.json'
# 08/07/2024 17:00:33 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:33 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:33 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:33 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:34 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:34 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:34 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:34 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:34 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:34 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:35 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:35 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:35 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:35 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:36 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:36 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:36 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:36 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:37 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:37 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:38 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:38 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:38 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:38 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:39 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:39 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:40 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:40 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:40 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:40 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:41 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:41 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:42 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:42 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
# 08/07/2024 17:00:43 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:43 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:44 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:44 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:45 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:45 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:46 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:46 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:47 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:47 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:48 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:48 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:49 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:49 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:51 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:51 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:52 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:52 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:53 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:53 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:55 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:55 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:56 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:56 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:00:58 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:00:58 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:00 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:00 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:02 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:02 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:03 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:03 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:05 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:05 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:07 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:07 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:09 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:09 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:11 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:11 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:13 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:13 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:15 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:15 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:17 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:17 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:19 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:19 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:22 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:22 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:24 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:24 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:27 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:27 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:29 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:29 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:32 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:32 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:34 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:34 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:37 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:37 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:40 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:40 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:42 - INFO - __main__ -   Processing example: 1000
# 08/07/2024 17:01:42 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:42 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:45 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:45 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:48 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:48 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:51 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:51 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:01:54 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:54 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
# 08/07/2024 17:01:57 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:01:57 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:00 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:00 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:03 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:03 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:06 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:06 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:09 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:09 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:13 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:13 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:16 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:16 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:20 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:20 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:23 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:23 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:27 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:27 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:30 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:30 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:34 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:34 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:38 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:38 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:43 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:43 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:47 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:47 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:51 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:51 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:55 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:55 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:02:59 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:02:59 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:03 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:03 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:07 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:07 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:12 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:12 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:16 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:16 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:21 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:21 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:26 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:26 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:30 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:30 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:35 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:35 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:39 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:39 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:44 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:44 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:49 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:49 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:54 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:54 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:03:59 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:03:59 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:04:04 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:04:04 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:04:09 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:04:09 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:04:14 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:04:14 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:04:19 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:04:19 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:04:24 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:04:24 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:04:29 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:04:29 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
# 08/07/2024 17:04:35 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:04:35 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:04:40 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:04:40 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:04:45 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:04:45 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:04:50 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:04:50 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:04:56 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:04:56 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:05:02 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:05:02 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:05:08 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:05:08 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:05:14 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:05:14 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:05:19 - INFO - __main__ -   Processing example: 2000
# 08/07/2024 17:05:19 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:05:19 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:05:26 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:05:26 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:05:31 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:05:31 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:05:37 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:05:37 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:05:44 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:05:44 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:05:50 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:05:50 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:05:56 - INFO - __main__ -   Writing predictions to: output_path/epoch_2_predictions.json
# 08/07/2024 17:05:56 - INFO - __main__ -   Writing nbest to: output_path/epoch_2_nbest_predictions.json
#
#
#
# LENGTH: 5945
#
#
#
# 08/07/2024 17:06