# %%
# !python run_squad2a.py --bert_model bert-base-cased --do_predict --predict_batch_size 20 --num_train_epochs 3.0 --max_seq_length 384 --doc_stride 128 --learning_rate 3e-5 --output_dir output_path --predict_file after_3_epochs.csv --predict_tag_file dev_span_sa.json
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# 08/21/2024 13:34:29 - INFO - __main__ -   device: cuda n_gpu: 1, distributed training: False, 16-bits training: False
# 08/21/2024 13:34:29 - INFO - pytorch_pretrained_bert.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased-vocab.txt from cache at /home/hmoradis/.cache/torch/pytorch_transformers/5e8a2b4893d13790ed4150ca1906be5f7a03d6c4ddf62296c383f6db42814db2.e13dbb970cb325137104fb2e5f36fe865f27746c6b526f6352861b1980eb80b1
# 08/21/2024 13:34:29 - INFO - pytorch_pretrained_bert.modeling -   loading archive file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased.tar.gz from cache at /home/hmoradis/.cache/torch/pytorch_transformers/distributed_-1/a803ce83ca27fecf74c355673c434e51c265fb8a3e0e57ac62a80e38ba98d384.681017f415dfb33ec8d0e04fe51a619f3f01532ecea04edbfd48c5d160550d9c
# ...

# %%
# !mv output_path/epoch_2_predictions.json ../
