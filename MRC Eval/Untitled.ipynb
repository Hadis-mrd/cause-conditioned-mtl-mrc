# %%
import pandas as pd
df = pd.read_csv("BARTEPOCH3.csv")

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0                       qid  \
# 0                0         0.0  5ad39d53604f3c001a3fe8d1
# 1                1         1.0  5ad39d53604f3c001a3fe8d2
# 2                2         2.0  5ad39d53604f3c001a3fe8d3
# 3                3         3.0  5ad39d53604f3c001a3fe8d4
# 4                4         4.0  5ad3a266604f3c001a3fea27
# ...            ...         ...                       ...
# 5936          5936         NaN  5ad28a57d7d075001a4299b3
# 5937          5937         NaN  5ad28ad0d7d075001a4299cc
# 5938          5938         NaN  5ad28ad0d7d075001a4299cd
# 5939          5939         NaN  5ad28ad0d7d075001a4299ce
# 5940          5940         NaN  5ad28ad0d7d075001a4299cf
#
#                   OU model2 answer span  OU model2 start  OU model2 end  \
# 0                           The Normans                0             11
# 1                             Normandy,              136            146
# ...
